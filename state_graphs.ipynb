# %%
### Import the necessary libraries and dependencies.
# Import libraries and dependencies
import pandas as pd
from pathlib import Path

# %matplotlib inline

### Read CSV in as DataFrame
# Set the path
us_csvpath = Path("ufo_df_us.csv")

# Read in the CSV as a DataFrame
us_df = pd.read_csv(
    us_csvpath, index_col="datetime", infer_datetime_format=True, parse_dates=True
)
us_df = df.sort_index()
us_df.head()
# Out:
# /opt/anaconda3/envs/project1env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (13,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                            date  year month  date.1        day      time  \
# datetime
# 1906-11-11 00:00:00  1906-11-11  1906   Nov      11     Sunday   0:00:00
# 1910-01-02 00:00:00  1910-01-02  1910   Jan       2     Sunday   0:00:00
# 1910-06-01 15:00:00  1910-06-01  1910   Jun       1  Wednesday  15:00:00
# 1916-04-05 13:00:00  1916-04-05  1916   Apr       5  Wednesday  13:00:00
# 1920-06-11 21:00:00  1920-06-11  1920   Jun      11     Friday  21:00:00
#
#                                               city  \
# datetime
# 1906-11-11 00:00:00                 wien (austria)
# 1910-01-02 00:00:00              kirksville (near)
# 1910-06-01 15:00:00                    wills point
# ...

# %%
### Read au data CSV in as DataFrame
# Set the path
au_csvpath = Path("ufo_df_au.csv")

# Read in the CSV as a DataFrame
au_df = pd.read_csv(
    au_csvpath, index_col="datetime", infer_datetime_format=True, parse_dates=True
)
au_df = au_df.sort_index()
au_df.head()
# Out:
#                            date  year month  date.1       day      time  \
# datetime
# 1958-06-06 18:45:00  1958-06-06  1958   Jun       6    Friday  18:45:00
# 1960-07-29 19:30:00  1960-07-29  1960   Jul      29    Friday  19:30:00
# 1963-03-29 20:00:00  1963-03-29  1963   Mar      29    Friday  20:00:00
# 1967-01-07 21:30:00  1967-01-07  1967   Jan       7  Saturday  21:30:00
# 1968-06-01 00:00:00  1968-06-01  1968   Jun       1  Saturday   0:00:00
#
#                                                       city  \
# datetime
# 1958-06-06 18:45:00             sydney (nsw&#44 australia)
# 1960-07-29 19:30:00                  melbourne (australia)
# 1963-03-29 20:00:00  clunes/maryborough (near) (australia)
# 1967-01-07 21:30:00                    woy woy (australia)
# 1968-06-01 00:00:00                   brisbane (australia)
#
#                     location (land, in space, at sea, in flight) state  \
# datetime
# ...

# %%
### US sightings by state

# %%
# Create df of sightings per state
us_sightings_state  = us_df[["state","sightings"]]
us_sightings_per_state = us_sightings_state.groupby("state").sum()

# Show top 20 countries for sightings
us_sightings_per_state.nlargest(10, "sightings")
# Out:
#        sightings
# state
# ca          9655
# wa          4268
# fl          4200
# tx          3677
# ny          3219
# az          2689
# il          2645
# pa          2582
# oh          2426
# mi          2071

# %%
# Plot sightings per state on bar chart
us_sightings_per_state.plot.bar()
# Out:
# <AxesSubplot:xlabel='state'>

# %%
### AU sightings by state

# %%
# Create df of sightings per state
au_sightings_state  = au_df[["state","sightings"]]
au_sightings_per_state = au_sightings_state.groupby("state").sum()

# Show top 20 countries for sightings
au_sightings_per_state.nlargest(10, "sightings")
# Out:
#        sightings
# state
# nsw          179
# qld          135
# vic          133
# wa            79
# sa            56
# act           17
# tas           13
# nt             8

# %%
au_sightings_per_state.plot.bar()
# Out:
# <AxesSubplot:xlabel='state'>

# %%
### Read India data CSV in as DataFrame
# Set the path
in_csvpath = Path("ufo_df_in.csv")

# Read in the CSV as a DataFrame
in_df = pd.read_csv(
    in_csvpath, index_col="datetime", infer_datetime_format=True, parse_dates=True
)
in_df = in_df.sort_index()
in_df.head()
# Out:
#                            date  year month  date.1       day      time  \
# datetime
# 1977-05-01 19:00:00  1977-05-01  1977   May       1    Sunday  19:00:00
# 1977-07-15 16:30:00  1977-07-15  1977   Jul      15    Friday  16:30:00
# 1978-06-30 20:00:00  1978-06-30  1978   Jun      30    Friday  20:00:00
# 1980-04-20 00:00:00  1980-04-20  1980   Apr      20    Sunday   0:00:00
# 1982-05-15 19:00:00  1982-05-15  1982   May      15  Saturday  19:00:00
#
#                                                city  \
# datetime
# 1977-05-01 19:00:00  bhandara (near nagpur) (india)
# 1977-07-15 16:30:00            korba&#44 mp (india)
# 1978-06-30 20:00:00  bhandara (near nagpur) (india)
# 1980-04-20 00:00:00               hyderabad (india)
# 1982-05-15 19:00:00                    pune (india)
#
#                     location (land, in space, at sea, in flight)  \
# datetime
# 1977-05-01 19:00:00                                         land
# ...

# %%
### India sightings by state

# %%
# Create df of sightings per state
in_sightings_state  = in_df[["state","sightings"]]
in_sightings_per_state = in_sightings_state.groupby("state").sum()

# Show top 20 countries for sightings
in_sightings_per_state.nlargest(10, "sightings")
# Out:
#                sightings
# state
# Maharashtra           38
# Karnataka             23
# Delhi                 17
# Tamil Nadu            16
# Haryana               12
# Telangana             12
# Uttar Pradesh         12
# Kerala                11
# Chandigarh             9
# Punjab                 8

# %%
# Plot sightings per country on bar chart
in_sightings_per_state.plot.bar()
# Out:
# <AxesSubplot:xlabel='state'>
